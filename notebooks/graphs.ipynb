# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Paths

# %%
import os
import pathlib
import sys

# %%
if not 'google.colab' in str(get_ipython()):
    
    notebooks = os.getcwd()
    parent = str(pathlib.Path(notebooks).parent)
    sys.path.append(parent)
    sys.path.append(os.path.join(parent, 'review'))

# %% [markdown]
# <br>
#
# ### Libraries

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <br>
#
# **Custom**

# %%
import review.graphics.settings

# %%
settings = review.graphics.settings.Settings()

settings.aesthetics()
settings.layout()

# %% [markdown]
# <br>
# <br>
#
# ## Examples

# %% [markdown]
# ### Country & Population

# %%
country = ['China', 'India', 'United Sates', 'Indonesia', 'Pakistan', 'Brazil']
population = [1439323776, 1380004385, 331002651, 273523615, 220892340, 212559417]

plt.figure(figsize=(4.5, 3.9));
plt.bar(country, population);
plt.xticks(rotation=90);

plt.tick_params(axis='both', labelsize='medium')

# %% [markdown]
# <br>
#
# ### Populations by Year

# %%
year = [1851, 1861, 1871, 1881, 1891,
        1901, 1911, 1921, 1931, 1941,
        1951, 1961, 1971, 1981, 1991,
        2001, 2011]
population = [ 27368800, 28917900, 31484700, 34934500, 37802400,
               41538200, 42189800, 43904100, 46073600, 44870400,
               50286900, 52807400, 55928000, 56357500, 57438700,
               59113016, 63285145 ]

plt.figure(figsize=(4.1, 3.9));
plt.plot(year, population);
plt.xticks(rotation=90);

plt.title('Population of the\nUnited Kingdom Over Time\n');
plt.xlabel('\nYear');
plt.ylabel('Population\n');

plt.tick_params(axis='both', labelsize='medium')

# %% [markdown]
# <br>
#
# ### Distribution of Births

# %%
url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/births/US_births_2000-2014_SSA.csv'
mydata = pd.read_csv(filepath_or_buffer=url)

plt.figure(figsize=(4.1, 3.9));
plt.boxplot(mydata.births, notch=True, vert=False);
plt.xticks(rotation=90)

plt.title('Distribution of\n# of Daily Births in the USA (2000-2014)\n')
plt.xlabel('\nNumber of Births')

plt.tick_params(axis='both', labelsize='medium')

# %% [markdown]
# <br>
#
# ### Sales

# %%
temperature = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
icecreamsales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

plt.figure(figsize=(3.6, 3.3))
plt.scatter(temperature, icecreamsales)
plt.xticks(rotation=90)

plt.title('Ice Cream Sales vs.\nTemperature\n')
plt.xlabel('\nTemperature (degrees C)')
plt.ylabel('Ice cream sales\n')

plt.tick_params(axis='both', labelsize='medium')
